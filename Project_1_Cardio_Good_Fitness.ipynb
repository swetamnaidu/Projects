# %% [markdown]
# <font color=darkcyan>
# <font size =5>
# 1.1 Loading all required libraries

# %%
import numpy as np # Importing and loading Numpy
import pandas as pd # Importing and loading Pandas
import matplotlib.pyplot as plt # Importing and loading Matplotlib
import seaborn as sns # Importing and loading Seaborn
sns.set_style('darkgrid') # Set graph background to grid patterned in dark grey.

# %% [markdown]
# <font color=darkcyan>
# <font size =5>
# 1.2 Importing the Data Set

# %%
cardio = pd.read_csv('CardioGoodFitness.csv') # Importing the data Set Cardio good fitness as cardio

# %%
pd.read_csv('CardioGoodFitness.csv')
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# <font color=darkblue>
# <font size =2>
# # Observations :
# The dataset given CardioGoodFitness.csv file has been succefully imported.

# %% [markdown]
# <font color=darkcyan>
# <font size =5>
# 1.3 Structural Overview of the Data Set

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.3.1 Data head

# %%
cardio.head(10) # Check and display the top 10 rows
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %% [markdown]
# <font color=darkblue>
# <font size =2>
# # Observations :
# The dataset looks clean and consistent with the description provided.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.3.2 Data columns of the given Cardio Fitness Data Set

# %%
cardio.columns # Name of columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# <font color=darkblue>
# <font size =2>
# # Observations :
# The dataset consists of the above columns.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.3.3 Checking the data shape

# %%
cardio.shape # check the size od data set
# Out:
# (180, 9)

# %% [markdown]
# <font color=darkblue>
# <font size =2>
# # Observations :
# We have 180 observations of 9 columns

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.3.4 Checking the detailed information of the columns like data type, count, etc.

# %%
cardio.info() # check data types of all columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# <font color=darkblue>
# <font size =2>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#
# 1. Product,Gender and Marital Status is object data type
# 2. All the other variables Age, Education, Usage, Fitness,Income and Miles are numerical.

# %%
cardio.dtypes.value_counts()
# Out:
# int64     6
# object    3
# dtype: int64

# %% [markdown]
# <font color=darkblue>
# <font size =2>
# # Observations :
# Of the given columns 6 have numerical values and 3 have object data types. We have no float Data types

# %% [markdown]
# <font color= darkorange >
# <font size =4.5>
# 1.3.5 Calculating the statistical data for the given data frame

# %%
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#
# 1. Age of the customers using this product varies from 18 years to 50 years.
# 2. The number of miles each customer plans on running per week has a very large range variation ranging fro 21 to 360 miles.
# 3. Also the customer income has a very huge range.
# 2. Usage and Fitness have their mean almost equivalent to its 50% median. Hence we can say that they have a symmetrical distribution.

# %% [markdown]
# <font color= darkorange >
# <font size =4.5>
# 1.3.6 Checking for missing values

# %%
def missing_check(df):
    total = df.isnull().sum().sort_values(ascending=False)   # total number of null values
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)  # percentage of values that are null
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  # putting the above two together
    return missing_data # return the dataframe
missing_check(data)
# Out:
#                Total  Percent
# Miles              0      0.0
# Income             0      0.0
# Fitness            0      0.0
# Usage              0      0.0
# MaritalStatus      0      0.0
# Education          0      0.0
# Gender             0      0.0
# Age                0      0.0
# Product            0      0.0

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above table we can see that there are no missing values on any of the columns.

# %% [markdown]
# <font color=darkcyan>
# <font size =5>
# 1.4 Univariate Analysis

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.1 Product count histogram

# %%
plt.figure(figsize=(3,5)) # Setting the graph size
sns.histplot(cardio.Product, kde =False); # Ploting a histogram, without kde plot.

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graph we can see that product TM195 is the most commnly used treadmill by customers.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.2 Customer Age distribution

# %%
sns.histplot(cardio.Age, kde =True); # Ploting a histogram, with kde

# %%
plt.figure(figsize= (5,3))
ax= sns.violinplot(x= 'Age', data = cardio); # Plot  a violin graph

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graphs we can see that the maximum customers using the treadmills lie in the age bracket of 20 to 30 years, as the age increases people using fitness equipment reduces. People in age group 40-50 years are least likely to use treadmills.

# %%
plt.figure(figsize=(10,5)) # makes the plot wider
plt.axvline(data['Age'].mean(), color='m', linewidth=1)
plt.axvline(data['Age'].median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(data['Age'].mode()[0], color='w', linestyle='dashed', linewidth=1)
ax = plt.hist(data.Age, color='darkcyan') # plots a simple histogram

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.3 Customer Gender Distribution

# %%
plt.figure(figsize=(3,5)) 
sns.histplot(cardio.Gender, kde =False);

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graph we can see that men tend to use treadmills more than women.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.4 Customer Educational Influence

# %%
plt.figure(figsize= (5,3))
ax= sns.violinplot(x= 'Education', data = cardio);

# %%
sns.histplot(cardio.Education, kde =True);

# %%
plt.figure(figsize=(10,5)) # makes the plot wider
plt.axvline(data['Education'].mean(), color='m', linewidth=1)
plt.axvline(data['Education'].median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(data['Education'].mode()[0], color='w', linestyle='dashed', linewidth=1)
ax = plt.hist(data.Education, color='darkcyan') # plots a simple histogram

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graph we can see that

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.5 Customer Marital Status

# %%
plt.figure(figsize=(3,5)) 
sns.histplot(cardio.MaritalStatus)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Count'>

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graph we can see that partnered people tend to use treadmill more than single people.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.5 Customer Usage per week

# %%
sns.histplot(cardio.Usage);

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graph we can see that maximum customers use the treadmill around 3 to 4 times a week. Very few people use it 6 to 7 times a week.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.5 Customer Fitness level

# %%
sns.histplot(cardio.Fitness);

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : For a range of customer fitness level ranging from 1 to 5. Assuming 1 being the lowest fitness to 5 being most fit. From the above graph we can see that people with fitness level 3 are most likely to use our product. Where as those with fitness level 1 are least likely to use it.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.5 Customer Income

# %%
sns.histplot(cardio.Income, kde = True);

# %%
plt.figure(figsize= (5,3))
ax= sns.violinplot(x= 'Income', data = cardio);

# %%
plt.figure(figsize= (5,3))
ax= sns.boxplot(x= 'Income', data = cardio);

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graphs we can see that people with income ranging from 45k to 60 k are mostly using the treadmills, as income increases they are least likely to use treadmills for their fitness routine.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.4.5 Miles expected to be run per week by customer

# %%
sns.histplot(cardio.Miles,kde =True);

# %%
plt.figure(figsize= (5,3))
ax= sns.violinplot(x= 'Miles', data = cardio);

# %%
plt.figure(figsize= (5,3))
ax= sns.boxplot(x= 'Miles', data = cardio);

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations
#    : From the above graphs we can see thatmost customers targeted miles range from 60 to 125 miles per week. Very few people tend to have goals more than 175 miles per week or less than 50 miles per week.

# %% [markdown]
# <font color=darkcyan>
# <font size =5>
# 1.5 Bivariate Analysis

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.5.1 Pair plots of all numerical data

# %%
sns.pairplot(data);

# %%
correlation = cardio.corr() 
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f', center = 1 )  # heatmap
plt.show()

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#
# 1. Usage has a positive correlation with miles expected to run and fitness level of the customer.
# 2. Education and Income are positively correlated with each other

# %% [markdown]
# <font color= darkorange >
# <font size =4.5>
# 1.5.2 Correlation between different product and usasge

# %%
x = cardio.groupby('Product').sum()['Usage']
print(x)
# Out:
# Product
# TM195    247
# TM498    184
# TM798    191
# Name: Usage, dtype: int64

# %%
# Graph plotting total usage for a given product

x.plot(x='Product',y='Usage',kind='bar',figsize=(5,5))
plt.show()

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#      From the above graph we can see that the overall usage of the treadmill with model no. TM195 is more than the other two products.

# %%
# Graph plotting usage per week of products 

plt.figure(figsize=(5,5))
ax = sns.barplot(x='Product', y='Usage', data=cardio, palette='muted')

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#    Assuming usage refers to usage per week of the product, we can see that customers with product TM798 tend to use it more in a given week.

# %% [markdown]
# <font color= darkorange >
# <font size =4.5>
# 1.5.3 Correlation between different Fitness and usasge

# %%
# Graph plotting usage per week of customers of varied fitness level


plt.figure(figsize=(5,5))
ax = sns.barplot(x='Fitness', y='Usage', data=cardio,  palette='muted')

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#    Assuming usage refers to usage per week of the product and fitness level 5 is the most fit, we can say that as fitness level increase usage also increases, they are directly proportional to each other.

# %% [markdown]
# <font color= darkorange >
# <font size =4.5>
# 1.5.4 Correlation between different Fitness and Miles

# %%
# Graph plotting usage per week of customers of varied fitness level


plt.figure(figsize=(5,5))
ax = sns.lineplot(x='Fitness', y='Miles', data=cardio,  palette='muted')

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color= darkorange >
# <font size =4.5>
# 1.5.5 Correlation between different Age and Gender

# %%
# Graph plotting usage per week of customers of varied fitness level


plt.figure(figsize=(5,5))
ax = sns.boxplot(x='Age', y='Gender', data=cardio,  palette='muted')

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#   Male customers tend to use treadmill in a wider Age range than Female Customers.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.5.6 Correlation between Product and Age

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=cardio,x='Age',y='Product', palette ='muted')
plt.show()

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#
# 1. From the above graps we can see that product TM195 is used by a more varied age range as compared to TM798 .
# 2. TM798 is more concentrated in age groups 25-30 years.
# 3. Therrfore we can say if we are targeting a wider customer age group, product TM195 and TM498 are more used by customers

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.5.7 Correlation between Product and Income

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=cardio,x='Income',y='Product', palette ='muted')
plt.show()

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#
# 1. Customers with higher income tend to use product TM798 more. Lower income group doesnot tend to use this product.
# 2. Product TM195 is used more by lower income and mid range income customers.
# 3. Product TM498 is used by mid income range customers.
# 4. From the above data we can say that product TM798 is more expensive as compared to other two products.

# %% [markdown]
# <font color=darkcyan>
# <font size =5>
# 1.6 Multivariate Analysis

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.6.1 Correlation between Product, customer fitness and its Usage

# %%
# Bar plot using 3 variables
sns.barplot(data=cardio,x='Usage',y='Fitness',hue='Product', palette ='muted')
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#
# 1. TM798 is more used by customers with higher fitness level.
# 2. Also the customers tend to use it more times in a week.
# 3. Product TM195 and TM498 are used by customers with low to moderate fitness levels.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.6.2 Correlation between Product, Gender and  Usage

# %%
# numerical with categorical values
plt.figure(figsize=(10,5))
sns.barplot(data=cardio,x='Usage',y='Gender',hue='Product', palette ='muted')
plt.show()

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#  TM798 is more used by both male and female customers as compared to other products.

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.6.3 Correlation between Marital Status, Gender and  Usage

# %%
product_usage = data['Usage'].groupby([data['MaritalStatus'],data['Gender']]).sum()  # number of suicides by country and sex
product_usage = product_usage.reset_index().sort_values(by='Usage',ascending=False) # sort in descending order


fig = plt.figure(figsize=(15,5))
plt.title('Product Usage')

sns.barplot(y='MaritalStatus',x='Usage',hue='Gender',data = product_usage, palette='Set2');

plt.ylabel('Customer Atrribute')
plt.tight_layout()

# %% [markdown]
# <font color=darkblue>
# <font size =3>
# # Observations

# %% [markdown]
# <font color = 'darkblue'>
#
# Product Usage of partnered customers is more than single customers. And more male customers use the treadmill than female customers

# %% [markdown]
# <font color=darkorange>
# <font size =4.5>
# 1.6.4 Correlation between Product, Age and  Usage

# %%
product_usage = data['Usage'].groupby([data['Age'],data['Product']]).sum()  # number of suicides by country and sex
product_usage = product_usage.reset_index().sort_values(by='Age',ascending=False) # sort in descending order


fig = plt.figure(figsize=(15,5))
plt.title('Product Usage as per age')

sns.lineplot(y='Age',x='Usage',hue='Product',data = product_usage, palette='Set2');

plt.ylabel('Age')
plt.tight_layout()

# %% [markdown]
# <font color=darkcyan>
# <font size =5>
# 1.7 Conclusions

# %% [markdown]
# <font color = 'darkcyan'>
#
# 1. We can conclude that most profitable customer segments are in Age group of 25-30 Years.
# 2. Product TM195 has a wider age range, so a single product can cater to all the members of the family.
# 3. Product TM798 looks more appealing to people with high fitness level. Also people with higher income level seem to prefer this product.
# 4. Product TM195 is less expensive and people with low to moderate fitness level prefer it.
# 5. More male customers than female customers are using treadmills.
# 6. Also more partnered customers use treadmills than single customers.
# 7. TM798 gets used more per week as compared to other products.
#
#  Difference between customers of each product
#
# 1)TM195 - Wider customer age range, Low to moderate fitness level of customer, Least expensive, Targeted customers of lower to mid level income group.
#
# 2)TM498 - Moderate customer age range, moderate to low fitness level.
#
# 3)TM798 - Target customer Age group 25-30 years, Higher fitness level of customers, Most expensive.
